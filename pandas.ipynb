# %%
import pandas as pd
import numpy as np

# %%
dict1={
    "name":['saurabh','shruti','khushi','sanskar'],
    "marks":[98,99,100,102],
    "city":['pune','bangluru','nagar','pcmc']
}

# %%
df=pd.DataFrame(dict1)

# %%
print(df.head())
# Out:
#       name  marks      city
# 0  saurabh     98      pune
# 1   shruti     99  bangluru
# 2   khushi    100     nagar
# 3  sanskar    102      pcmc

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_noindex.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.to_csv('friends_noindex.csv',index=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df.describe()
# Out:
#             marks
# count    4.000000
# mean    99.750000
# std      1.707825
# min     98.000000
# 25%     98.750000
# 50%     99.500000
# 75%    100.500000
# max    102.000000

# %%
data1=pd.read_csv('SM_data.csv')

# %%
data1.index=data1['Date']

# %%
print(type(data1['SM10']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(data1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
ser=pd.Series(np.random.rand(34))
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
data=pd.read_csv('SM_data.csv')
data=data.set_index('Date')
data.index = pd.to_datetime(data.index, format='%d-%m-%Y')

# %%
data.T
# Out:
# Date             1980-01-01  1980-01-02  1980-01-03  1980-01-04  1980-01-05  \
# SM10              17.670000   17.670000   17.480000   17.480000   17.300000
# SM30              20.133333   20.133333   20.066667   20.066667   20.000000
# Sm60              21.133333   21.133333   21.066667   21.066667   20.983333
# SM100             31.370000   31.370000   31.360000   31.360000   31.340000
# St10              24.150000   24.150000   24.150000   24.150000   23.250000
# St30              23.350000   23.350000   23.650000   23.650000   23.650000
# St60              23.450000   23.450000   23.550000   23.550000   23.650000
# St100             24.450000   24.450000   24.450000   24.450000   24.450000
# Rain               0.000000    0.000000    0.000000    0.000000    0.000000
# Air_Temperature   22.290000   22.980000   21.620000   21.420000   23.070000
# Unnamed: 11             NaN         NaN         NaN         NaN         NaN
# ...

# %%
data.sort_index
# Out:
# <bound method DataFrame.sort_index of              SM10       SM30       Sm60  SM100   St10   St30   St60  St100  \
# Date
# 1980-01-01  17.67  20.133333  21.133333  31.37  24.15  23.35  23.45  24.45
# 1980-01-02  17.67  20.133333  21.133333  31.37  24.15  23.35  23.45  24.45
# 1980-01-03  17.48  20.066667  21.066667  31.36  24.15  23.65  23.55  24.45
# 1980-01-04  17.48  20.066667  21.066667  31.36  24.15  23.65  23.55  24.45
# 1980-01-05  17.30  20.000000  20.983333  31.34  23.25  23.65  23.65  24.45
# ...           ...        ...        ...    ...    ...    ...    ...    ...
# 2021-11-17  32.81  31.633333  29.383333  33.53  24.85  24.35  24.05  24.35
# 2021-11-18  31.61  31.400000  29.533333  33.47  24.55  24.35  24.15  24.35
# 2021-11-19  31.16  31.133333  29.650000  33.42  24.75  24.35  24.15  24.35
# 2021-11-20  30.51  30.833333  29.716667  33.37  24.75  24.35  24.25  24.35
# 2021-11-21  30.23  30.566667  29.733333  33.33  25.15  24.45  24.25  24.35
#
# ...
